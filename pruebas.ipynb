# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
# Sacamos los nombres de los ficheros
paths_comunidades = [path for path in os.listdir('data/comunidades/') if path.endswith('.xlsx')]

# Creamos una lista para ir añadiendo los dataframes leidos
dfs = list()

for path_comunidad in paths_comunidades:
    # Extraemos el nombre de la comunidad
    comunidad = os.path.splitext(path_comunidad)[0]

    # Leemos el fichero, reseteamos el index y le cambiamos el nombre de la columna a ID
    fichero = pd.read_excel('./data/comunidades/'+path_comunidad).reset_index(drop=True).rename(columns={'Unnamed: 0': 'ID'})

    # Descartamos las filas donde el la columna BIO no es nula.
    # Asignamos el nombre de la comunidad a una nueva columna.
    fichero_sin_bio = fichero[fichero['SEGMENTO BIO'].isna()].reset_index(drop=True).assign(COMUNIDAD=comunidad)

    # Añadimos el fichero leido a nuestra lista de dataframes
    dfs.append(fichero_sin_bio)

# Montamos el dataframe final
datos = pd.concat(dfs, ignore_index=True)

# Eliminamos la columna SEGMENTO BIO
datos.drop('SEGMENTO BIO', axis=1, inplace=True)

# %%
datos.shape
# Out:
# (9432, 166)

# %%
datos.head(20)
# Out:
#                             ID           SECTOR    SECCION  \
# 0                    TOTAL PGC              NaN        NaN
# 1              ALIM. Y BEBIDAS  ALIM. Y BEBIDAS        NaN
# 2                    ALIM.SECA  ALIM. Y BEBIDAS  ALIM.SECA
# 3                       ACEITE  ALIM. Y BEBIDAS  ALIM.SECA
# 4                    GIRASOL..  ALIM. Y BEBIDAS  ALIM.SECA
# 5                        OLIVA  ALIM. Y BEBIDAS  ALIM.SECA
# 6                RESTO ACEITES  ALIM. Y BEBIDAS  ALIM.SECA
# 7              ADITIVOS COCINA  ALIM. Y BEBIDAS  ALIM.SECA
# 8                     ADEREZOS  ALIM. Y BEBIDAS  ALIM.SECA
# 9                     ESPECIAS  ALIM. Y BEBIDAS  ALIM.SECA
# 10  HARINAS/SEMOLAS Y TAPIOCAS  ALIM. Y BEBIDAS  ALIM.SECA
# 11      POTENCIADORES DE SABOR  ALIM. Y BEBIDAS  ALIM.SECA
# 12                         SAL  ALIM. Y BEBIDAS  ALIM.SECA
# 13                     VINAGRE  ALIM. Y BEBIDAS  ALIM.SECA
# 14        ALIMENTOS INFANTILES  ALIM. Y BEBIDAS  ALIM.SECA
# 15              LECHE INFANTIL  ALIM. Y BEBIDAS  ALIM.SECA
# 16                    PAPILLAS  ALIM. Y BEBIDAS  ALIM.SECA
# 17           PLATOS INFANTILES  ALIM. Y BEBIDAS  ALIM.SECA
# 18          ALIMENTOS MASCOTAS  ALIM. Y BEBIDAS  ALIM.SECA
# 19            CUIDADO ANIMALES  ALIM. Y BEBIDAS  ALIM.SECA
#
#                CATEGORIA                     FAMILIA SEMANA 40-16  \
# 0                    NaN                         NaN          0.0
# 1                    NaN                         NaN          0.0
# 2                    NaN                         NaN          0.0
# 3                 ACEITE                         NaN          0.0
# 4                 ACEITE                   GIRASOL..          0.0
# 5                 ACEITE                       OLIVA          0.0
# 6                 ACEITE               RESTO ACEITES          0.0
# 18        34.13        41.25        31.88         35.5        34.67
# 19         3.02         3.03         2.95          3.2          3.2
#
#    SEMANA 41-19 SEMANA 42-19 SEMANA 43-19        COMUNIDAD
# 0       2412.15      2559.18      2647.53  Ceuta_y_Melilla
# 1       1288.87      1375.99      1442.49  Ceuta_y_Melilla
# 2        739.01       813.17       891.25  Ceuta_y_Melilla
# 3         61.45        60.28        63.69  Ceuta_y_Melilla
# 4         16.94        17.49        19.44  Ceuta_y_Melilla
# 5         41.63        39.63         41.4  Ceuta_y_Melilla
# 6          2.88         3.17         2.85  Ceuta_y_Melilla
# 7         14.38        14.43         17.0  Ceuta_y_Melilla
# 8          0.19         0.18         0.21  Ceuta_y_Melilla
# 9          6.22         6.01         8.11  Ceuta_y_Melilla
# 10         4.42         4.78         5.28  Ceuta_y_Melilla
# 11         0.14         0.13         0.14  Ceuta_y_Melilla
# 12         1.54         1.64         1.64  Ceuta_y_Melilla
# 13         1.87         1.69         1.62  Ceuta_y_Melilla
# 14        19.89        20.91        19.51  Ceuta_y_Melilla
# 15         8.46         9.58         8.76  Ceuta_y_Melilla
# 16         3.12         2.98         2.64  Ceuta_y_Melilla
# 17         8.31         8.34         8.11  Ceuta_y_Melilla
# 18        33.26        31.25        33.77  Ceuta_y_Melilla
# 19         2.67         2.82         2.79  Ceuta_y_Melilla
#
# [20 rows x 166 columns]

# %%
datos['COMUNIDAD'].value_counts()
# Out:
# Ceuta_y_Melilla       524
# Catalunya             524
# Canarias              524
# Navarra               524
# Castilla_La_Mancha    524
# C_Valenciana          524
# Extremadura           524
# La_Rioja              524
# Pais_Vasco            524
# Murcia                524
# Asturias              524
# Castilla_y_Leon       524
# Cantabria             524
# Baleares              524
# Madrid                524
# Andalucia             524
# Galicia               524
# Aragon                524
# TOTAL PGC               1
# Name: COMUNIDAD, dtype: int64

# %%
datos.isnull().sum().head(20)
# Out:
# ID                 0
# SECTOR            18
# SECCION           72
# CATEGORIA        270
# FAMILIA         1980
# SEMANA 40-16       0
# SEMANA 41-16       0
# SEMANA 42-16       0
# SEMANA 43-16       0
# SEMANA 44-16       0
# SEMANA 45-16       0
# SEMANA 46-16       0
# SEMANA 47-16       0
# SEMANA 48-16       0
# SEMANA 49-16       0
# SEMANA 50-16       0
# SEMANA 51-16       0
# SEMANA 52-16       0
# SEMANA 01-17       0
# SEMANA 02-17       0
# dtype: int64

# %%
totales_comunidad = datos[datos['ID'] == 'TOTAL PGC'].set_index('COMUNIDAD').T.iloc[5:]

# %%
totales_comunidad
# Out:
# COMUNIDAD    Ceuta_y_Melilla  Asturias    Aragon   Galicia  Andalucia  \
# SEMANA 40-16             0.0       0.0   10894.0       0.0   58480.38
# SEMANA 41-16             0.0       0.0   9770.08       0.0   57141.87
# SEMANA 42-16             0.0       0.0  10033.98       0.0   57290.85
# SEMANA 43-16             0.0       0.0  10569.76       0.0   59618.23
# SEMANA 44-16             0.0       0.0  10261.46       0.0   56082.58
# ...                      ...       ...       ...       ...        ...
# SEMANA 39-19         2853.67  22446.36   27198.2  54212.46  175969.14
# SEMANA 40-19         2844.06  22481.75  28762.09   56541.1  182950.03
# SEMANA 41-19         2412.15  21114.67  25231.16  51945.26  168597.49
# SEMANA 42-19         2559.18  21963.94  27756.19   54680.5  173629.17
# SEMANA 43-19         2647.53  21662.69  26811.75  52177.67   172746.3
#
# COMUNIDAD        Madrid  Baleares Cantabria Castilla_y_Leon    Murcia  \
# SEMANA 40-16   34775.94  14727.87   8352.53        19572.94       0.0
# SEMANA 41-16   33001.18  14442.84   7712.24        18342.98       0.0
# SEMANA 42-16   33943.81  13911.56   7835.98        18869.46       0.0
# SEMANA 43-16   35007.28  13613.85   8435.52        20258.06       0.0
# SEMANA 44-16   33989.72  12570.51   7699.21        18826.93       0.0
# ...                 ...       ...       ...             ...       ...
# SEMANA 39-19  148466.75   32996.6  14490.55         47749.1  28428.44
# SEMANA 40-19  154439.89  34023.32  14532.08        49217.56  29363.39
# SEMANA 41-19  142017.02  30865.15  13237.48        44465.79  27340.09
# SEMANA 42-19  149172.94  31354.86  14028.56         48939.5  28051.77
# SEMANA 43-19  148036.85  29921.51  13546.05        46251.45  27862.63
#
# COMUNIDAD     Catalunya Pais_Vasco La_Rioja Extremadura C_Valenciana  \
# SEMANA 40-16   70327.94   33151.33  3114.32     5598.69     47716.06
# SEMANA 41-16   68023.56   34488.84  2863.75     5366.86     46107.44
# SEMANA 42-16   68846.55   34488.99  2869.65     5556.26     45983.02
# SEMANA 43-16   72378.68   35815.16  3055.23     5978.39      47920.0
# SEMANA 44-16   70959.18   35738.11  2969.88     5375.58      45731.9
# ...                 ...        ...      ...         ...          ...
# SEMANA 39-19  171309.65   46221.68  6684.87    20165.38    121632.29
# SEMANA 40-19  174007.15   48603.86  7170.19    20789.07    122601.75
# SEMANA 41-19  161318.16   41283.56  6432.52     19122.6    111520.51
# SEMANA 42-19  167443.57   49189.84  6809.92    19766.56    119289.98
# SEMANA 43-19  168864.74   46811.66   6575.8    19532.96    116625.88
#
# COMUNIDAD    Castilla_La_Mancha   Navarra  Canarias  TOTAL PGC
# SEMANA 40-16           13823.75   7624.01  10887.32  TOTAL PGC
# SEMANA 41-16            12755.0    7340.7  10534.78  TOTAL PGC
# SEMANA 42-16           13126.11   7701.33  10598.53  TOTAL PGC
# SEMANA 43-16           13695.59   7679.61  10684.07  TOTAL PGC
# SEMANA 44-16           13250.86    7523.9  10851.14  TOTAL PGC
# ...                         ...       ...       ...        ...
# SEMANA 39-19           37284.35  12391.23  56434.31  TOTAL PGC
# SEMANA 40-19           39093.29  12988.61  60763.91  TOTAL PGC
# SEMANA 41-19           35726.29  11843.84   54070.5  TOTAL PGC
# SEMANA 42-19           37187.16  12786.32  53661.01  TOTAL PGC
# SEMANA 43-19           36326.04  12472.54  55353.85  TOTAL PGC
#
# [160 rows x 19 columns]

# %%
import plotly.express as px

fig = px.line(totales_comunidad)
fig.show()
